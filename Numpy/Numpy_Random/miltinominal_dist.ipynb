# %%
from numpy import random

x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])

print(x)
# Out:
# [2 0 0 1 1 2]

# %%
        print(x)
# Out:
# 1 [1 1 2 1 1 0]
# 2 [0 0 3 1 1 1]
# 3 [1 1 0 2 1 1]
# 4 [0 0 1 1 2 2]
# 5 [0 2 1 1 0 2]
# 6 [3 0 0 0 1 2]
# 7 [1 1 0 1 1 2]
# 8 [0 1 1 2 1 1]
# 9 [0 2 1 1 1 1]
# 10 [2 1 0 2 1 0]
# 11 [1 1 0 2 2 0]
# 12 [2 2 0 0 1 1]
# 13 [1 0 1 0 3 1]
# 14 [2 2 0 0 1 1]
# 15 [0 0 1 1 1 3]
# 16 [1 0 0 3 1 1]
# 17 [0 2 1 0 0 3]
# 18 [2 0 0 1 1 2]
# 19 [1 1 0 0 3 1]
# 20 [1 1 0 3 0 1]
# 21 [2 0 1 0 1 2]
# 22 [1 2 1 1 0 1]
# 23 [0 0 1 3 2 0]
# 24 [1 4 0 0 1 0]
# 25 [2 0 1 3 0 0]
# 26 [1 2 0 1 0 2]
# 27 [0 3 1 2 0 0]
# 28 [0 1 1 0 2 2]
# 29 [1 1 1 0 1 2]
# 30 [1 1 2 2 0 0]
# 31 [1 1 1 0 2 1]
# 32 [2 0 2 0 1 1]
# 33 [1 1 0 1 2 1]
# 34 [1 0 2 0 2 1]
# 35 [1 2 3 0 0 0]
# 36 [0 1 1 0 2 2]
# 37 [1 1 2 0 1 1]
# 38 [0 1 2 0 2 1]
# 39 [1 0 2 0 1 2]
# 40 [1 0 1 2 2 0]
# 41 [0 0 1 2 3 0]
# 42 [1 2 0 1 1 1]
# 43 [1 1 0 3 0 1]
# 44 [0 1 2 0 2 1]
# 45 [0 0 4 1 1 0]
# 46 [3 0 0 1 0 2]
# 47 [0 0 4 0 1 1]
# 48 [1 1 0 0 2 2]
# 49 [0 2 1 1 1 1]
# 50 [0 1 2 1 1 1]
# 51 [1 0 3 2 0 0]
# 52 [1 2 0 0 2 1]
# 53 [0 2 2 0 2 0]
# ...

# %%
        print(x)
