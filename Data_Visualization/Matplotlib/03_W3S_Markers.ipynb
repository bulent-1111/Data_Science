# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints= np.array([3,8,1,10])
# plt.plot(ypoints, marker = 'v') #. , o v ° ^ < > 1 2 3 4 8
# plt.plot(ypoints, marker = 'o') # s p P n * h H + x X D d 
# plt.plot(ypoints, marker = '^') # | _  daha da var
plt.plot(ypoints, marker = '|')
plt.show()

# %%
plt.plot(ypoints, marker = 's')
plt.show()

# %%
plt.plot(ypoints, marker = 's', color = 'c') 
# r g b c m y k w
plt.show()
