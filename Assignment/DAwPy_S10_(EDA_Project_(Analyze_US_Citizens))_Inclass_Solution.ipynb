# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">DAwPy-EDA PROJECT SOLUTION - (Analyze US Citizens)</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Read data from file</p>

# %%
df0 = pd.read_csv("adult_eda.csv")

df = df0.copy()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Try to understand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features? </p>

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.describe(include="object")
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.</p>

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
df.select_dtypes(include='object').describe()
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
df.sample(10)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 2843    41         Local-gov  344624  Some-college           10.0
# 1397    54  Self-emp-not-inc  114758       Masters           14.0
# 1286    47  Self-emp-not-inc  370119     Bachelors           13.0
# 30305   52           Private   95128  Some-college           10.0
# 25373   38      Self-emp-inc  124665     Bachelors           13.0
# 30229   17           Private  231438          11th            7.0
# 19694   45           Private   51744     Bachelors           13.0
# 1185    51                 ?  165637       Masters           14.0
# 17870   23           Private   53245     Bachelors           13.0
# 20873   47           Private  198223  Some-college           10.0
#
#            marital-status       occupation   relationship   race     sex  \
# 2843   Married-civ-spouse    Other-service        Husband  White    Male
# 1397   Married-civ-spouse            Sales        Husband  White    Male
# ...

# %%
#look at occupation column here

df.occupation.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#look at workclass column here

df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
df[df.workclass == '?']
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# ...

# %%
df[df.occupation == '?']
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 27      54         ?  180211  Some-college           10.0
# 61      32         ?  293936       7th-8th            4.0
# 69      25         ?  200681  Some-college           10.0
# 77      67         ?  212759          10th            6.0
# 106     17         ?  304873          10th            6.0
# ...    ...       ...     ...           ...            ...
# 32530   35         ?  320084     Bachelors           13.0
# 32531   30         ?   33811     Bachelors           13.0
# 32539   71         ?  287372     Doctorate            NaN
# 32541   41         ?  202822       HS-grad            9.0
# 32542   72         ?  129912       HS-grad            9.0
#
#               marital-status occupation   relationship                race  \
# 27        Married-civ-spouse          ?        Husband  Asian-Pac-Islander
# 61     Married-spouse-absent          ?  Not-in-family               White
# ...

# %%
df[df.isin(['?'])].any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country     True
# salary            False
# dtype: bool

# %%
df.workclass = df.workclass.str.replace('?', 'UNKNOWN')

# %%
df.workclass.value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# UNKNOWN              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#replace all '?' in whole df with 'Unknown'

df = df.replace({'?':'UNKNOWN'})

# %%
df.sample(10)
# Out:
#        age    workclass  fnlwgt     education  education-num  \
# 24725   19      Private  183589  Some-college           10.0
# 27186   20      Private  386864          10th            6.0
# 30089   21      Private  170302       HS-grad            9.0
# 6647    21  Federal-gov  169003          12th            8.0
# 25883   30      Private  155781       HS-grad            9.0
# 4103    21      Private  177125  Some-college           10.0
# 30915   28      Private  120475       HS-grad            9.0
# 29676   52      Private  117496     Bachelors           13.0
# 30691   20      Private  182342  Some-college           10.0
# 22448   49      Private   43206   Prof-school           15.0
#
#            marital-status         occupation    relationship   race     sex  \
# 24725       Never-married   Transport-moving             NaN  White    Male
# 27186       Never-married      Other-service  Other-relative  White    Male
# ...

# %%
df[df.isin(['?'])].any()
# Out:
# age               False
# workclass         False
# fnlwgt            False
# education         False
# education-num     False
# marital-status    False
# occupation        False
# relationship      False
# race              False
# sex               False
# capital-gain      False
# capital-loss      False
# hours-per-week    False
# native-country    False
# salary            False
# dtype: bool

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# UNKNOWN              1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 29170
# Mexico                          643
# UNKNOWN                         583
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# ...

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Do education and education_num columns hold similar information? If so drop the appropriate choice between them.</p>

# %%
df.education
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df['education-num']
# Out:
# 0        13.0
# 1        13.0
# 2         9.0
# 3         7.0
# 4        13.0
#          ...
# 32556    12.0
# 32557     9.0
# 32558     9.0
# 32559     9.0
# 32560     9.0
# Name: education-num, Length: 32561, dtype: float64

# %%
df.groupby('education')['education-num'].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
df.groupby('education')['education-num'].value_counts(dropna=False)
# Out:
# education     education-num
# 10th          6.0                916
#               NaN                 17
# 11th          7.0               1146
#               NaN                 29
# 12th          8.0                424
#               NaN                  9
# 1st-4th       2.0                161
#               NaN                  7
# 5th-6th       3.0                330
#               NaN                  3
# 7th-8th       4.0                631
#               NaN                 15
# 9th           5.0                503
#               NaN                 11
# Assoc-acdm    12.0              1044
#               NaN                 23
# Assoc-voc     11.0              1343
#               NaN                 39
# Bachelors     13.0              5247
#               NaN                108
# Doctorate     16.0               405
#               NaN                  8
# HS-grad       9.0              10215
#               NaN                286
# ...

# %%
df['education-num'].value_counts()
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
print(df['education-num'].value_counts().sum())
print(df['education'].value_counts().sum())
# Out:
# 31759
# 32561

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
#drop one of them here

df.drop('education-num', axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Take a look at correlation between variables and also see if there are some outliers in any of the columns.</p>

# %%
df.corr()
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
low = df.age.quantile(0.25)
low
# Out:
# 28.0

# %%
high = df.age.quantile(0.75)
high
# Out:
# 48.0

# %%
IQR = high-low
IQR
# Out:
# 20.0

# %%
#age column

IQR = 48 - 28

# %%
lower_lim = 28 - 1.5 * IQR
lower_lim
# Out:
# -2.0

# %%
upper_lim = 48 + 1.5 * IQR
upper_lim
# Out:
# 78.0

# %%
df[df["age"] >= 78]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 80    22
# 79    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 87     1
# 86     1
# Name: age, dtype: int64

# %%
df[df["age"] <= -2]["age"].value_counts()
# Out:
# Series([], Name: age, dtype: int64)

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 7))

x = 0
y = 0

for column in df.select_dtypes('number').columns:
    df[column].plot(kind = "box", ax=ax[x, y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df[(df["hours-per-week"] >= 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 5376    43           Private   86750     Assoc-voc  Married-civ-spouse
# 22557   55  Self-emp-not-inc   95149  Some-college  Married-civ-spouse
# 10266   56      Self-emp-inc  184598           9th  Married-civ-spouse
# 16992   19           Private  121074       7th-8th  Married-civ-spouse
# 25713   32           Private  183304     Assoc-voc  Married-civ-spouse
# 27764   38  Self-emp-not-inc  152621     Bachelors  Married-civ-spouse
# 29989   43         Local-gov  118853  Some-college  Married-civ-spouse
# 13858   37           Private   51264     Doctorate  Married-civ-spouse
# 13580   38  Self-emp-not-inc  112158       HS-grad  Married-civ-spouse
# 15356   90           Private   90523       HS-grad             Widowed
#
#              occupation relationship   race   sex  capital-gain  capital-loss  \
# 5376       Craft-repair      Husband  White  Male             0             0
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
#hours per week column

IQR = 45 - 40

# %%
upper_lim = 45 + 1.5 * IQR
upper_lim
# Out:
# 52.5

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
# 78 is the upper limit found above for age 

df[(df['age'] >= 78) & (df['hours-per-week'] >= 53)]
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 3777    80       Private   87518  Some-college       Never-married
# 5370    90     Local-gov  227796       Masters  Married-civ-spouse
# 7481    83       Private  195507       HS-grad             Widowed
# 7720    84       Private  241065       Masters       Never-married
# 8806    90       Private   87372   Prof-school  Married-civ-spouse
# 10546   78       UNKNOWN   33186       7th-8th  Married-civ-spouse
# 11996   90       Private   40388     Bachelors       Never-married
# 12830   81       Private  201398       Masters             Widowed
# 15356   90       Private   90523       HS-grad             Widowed
# 24395   83  Self-emp-inc  153183     Bachelors  Married-civ-spouse
#
#              occupation   relationship   race   sex  capital-gain  \
# 3777     Prof-specialty  Not-in-family  White  Male             0
# 5370    Exec-managerial        Husband  White  Male         20051
# ...

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">After looking at the outliers you can drop the rows which actually does not make any sense.</p>
# **Hint: You can check age and hours per week columns.**

# %%
df.shape

# %%
drop_index = df[(df['age'] >= 78) & (df['hours-per-week'] >= 53)].index
drop_index
# Out:
# Int64Index([3777, 5370, 7481, 7720, 8806, 10546, 11996, 12830, 15356, 24395], dtype='int64')

# %%
df.drop(index=drop_index, inplace=True)

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns

df[(df['age']>=78) & (df['hours-per-week']>=53)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
df.shape
# Out:
# (32551, 14)

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family' and 'Other-relative' values in this column with 'Unmarried'?</p>
# **Hint: You can check age and hours per week columns.**

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516  Bachelors       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 2   38           Private  215646    HS-grad            Divorced
# 3   53           Private  234721       11th  Married-civ-spouse
# 4   28           Private  338409  Bachelors  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital-gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital-loss  hours-per-week native-country salary
# 0             0              40  United-States  <=50K
# 1             0              13  United-States  <=50K
# ...

# %%
df.relationship.value_counts(dropna=False)
# Out:
# Husband           13189
# Not-in-family      8301
# NaN                5068
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df['relationship'] = df['relationship'].replace({np.nan:'Unmarried', 'Not-in-family':'Unmarried', 'Other-relative':'Unmarried'})
df['relationship']
# Out:
# 0        Unmarried
# 1          Husband
# 2        Unmarried
# 3          Husband
# 4             Wife
#            ...
# 32556         Wife
# 32557      Husband
# 32558    Unmarried
# 32559    Unmarried
# 32560         Wife
# Name: relationship, Length: 32551, dtype: object

# %%
df.relationship.value_counts()
# Out:
# Unmarried    17794
# Husband      13189
# Wife          1568
# Name: relationship, dtype: int64

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">How many of each race are represented in this dataset?</p>

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 27806
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">What is the average age of men/women?</p>

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education      marital-status  \
# 0   39         State-gov   77516  Bachelors       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 2   38           Private  215646    HS-grad            Divorced
# 3   53           Private  234721       11th  Married-civ-spouse
# 4   28           Private  338409  Bachelors  Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0       Adm-clerical    Unmarried  White    Male          2174             0
# 1    Exec-managerial      Husband  White    Male             0             0
# 2  Handlers-cleaners    Unmarried  White    Male             0             0
# 3  Handlers-cleaners      Husband  Black    Male             0             0
# 4     Prof-specialty         Wife  Black  Female             0             0
#
#    hours-per-week native-country salary
# 0              40  United-States  <=50K
# ...

# %%
average_age_men = df.loc[df['sex'] == 'Male', 'age'].mean()
average_age_men
# Out:
# 39.41267217630854

# %%
df[df.sex == 'Male'][["sex", 'age']]
# Out:
#         sex  age
# 0      Male   39
# 1      Male   50
# 2      Male   38
# 3      Male   53
# 7      Male   52
# ...     ...  ...
# 32553  Male   32
# 32554  Male   53
# 32555  Male   22
# 32557  Male   40
# 32559  Male   22
#
# [21780 rows x 2 columns]

# %%
average_age_men1 = df[df.sex == 'Male']['age'].mean()
average_age_men1
# Out:
# 39.41267217630854

# %%
round(average_age_men, 1)
# Out:
# 39.4

# %%
df.loc[df["sex"] == "Male", "age"].value_counts()
# Out:
# 35    630
# 37    629
# 34    629
# 33    620
# 36    611
#      ...
# 84      5
# 83      3
# 88      2
# 85      2
# 87      1
# Name: age, Length: 72, dtype: int64

# %%
plt.figure(figsize = (15, 7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women = df.loc[df.sex == 'Female','age'].mean()
average_age_women
# Out:
# 36.85823043357163

# %%
df.loc[df["sex"] == "Female", "age"].value_counts()
# Out:
# 20    363
# 23    359
# 19    356
# 22    342
# 21    329
#      ...
# 82      2
# 88      1
# 83      1
# 85      1
# 86      1
# Name: age, Length: 72, dtype: int64

# %%
plt.figure(figsize = (15, 7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">What is the percentage of people who have a Bachelor's degree?</p>

# %%
df.groupby('education').education.count()
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           645
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
df.groupby('education').education.count().loc['Bachelors']
# Out:
# 5353

# %%
# df.groupby('education').education.count().iloc[9]
# Out:
# 5353

# %%
# df.groupby('education').education.count().sum()
# Out:
# 32551

# %%
numarator = df.groupby('education').education.count().loc['Bachelors']

denominator = df.groupby('education').education.count().sum()

percentage_bachelors = numarator / denominator * 100

percentage_bachelors
# Out:
# 16.444963288378236

# %%
# short way to see the percentage of each category in education column

df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.322540
# Some-college    0.223956
# Bachelors       0.164450
# Masters         0.052840
# Assoc-voc       0.042456
# 11th            0.036097
# Assoc-acdm      0.032779
# 10th            0.028663
# 7th-8th         0.019815
# Prof-school     0.017665
# 9th             0.015791
# 12th            0.013302
# Doctorate       0.012688
# 5th-6th         0.010230
# 1st-4th         0.005161
# Preschool       0.001567
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100

round(percentage_bachelors, 1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : % {round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : % 16.4

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?</p>

# %%
df.salary.value_counts()
# Out:
# <=50K    24713
# >50K      7838
# Name: salary, dtype: int64

# %%
df.education.value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
higher_education = (df.education=='Bachelors') | (df.education=='Masters') | (df.education=='Doctorate')
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32551, dtype: bool

# %%
# df_high_edu = df[higher_education]
# df_high_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           UNKNOWN  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
df_high_edu = df.loc[(df.education=='Bachelors') | (df.education=='Masters') | (df.education=='Doctorate')]
df_high_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           UNKNOWN  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
df_high_edu[df_high_edu['salary'] == '>50K']
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           UNKNOWN  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# ...

# %%
count = df_high_edu[df_high_edu['salary'] == '>50K'].education.count()
count
# Out:
# 3484

# %%
# df_high_edu['salary'].value_counts()
# Out:
# <=50K    4002
# >50K     3484
# Name: salary, dtype: int64

# %%
# df_high_edu['salary'].value_counts().loc[">50K"]
# Out:
# 3484

# %%
#alternatif

shape = df_high_edu[df_high_edu['salary'] == '>50K'].shape[0]
shape
# Out:
# 3484

# %%
perc_high_edu = count / len(df)

# %%
perc_high_edu
# Out:
# 0.10703204202635863

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 10.7

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">What percentage of people without advanced education make more than 50K?</p>

# %%
lower_education = ~higher_education

# %%
df_low_edu = df[lower_education]
df_low_edu
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# ...    ...               ...     ...           ...                    ...
# 32556   27           Private  257302    Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374       HS-grad     Married-civ-spouse
# 32558   58           Private  151910       HS-grad                Widowed
# 32559   22           Private  201490       HS-grad          Never-married
# 32560   52      Self-emp-inc  287927       HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# ...

# %%
df_low_edu[df_low_edu.salary == '>50K']
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 27      54           UNKNOWN  180211  Some-college  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# ...

# %%
perc_low_edu = len(df_low_edu[df_low_edu.salary=='>50K']) / len(df)
perc_low_edu
# Out:
# 0.13375933151055266

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">What percentage of the people who work the minimum number of hours per week have a salary of >50K?</p>

# %%
df['hours-per-week'].value_counts()
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1471
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
# df[df['hours-per-week'] == df['hours-per-week'].min()]
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 189     58         State-gov  109567     Doctorate  Married-civ-spouse
# 1036    66      Self-emp-inc  150726           9th  Married-civ-spouse
# 1262    69           UNKNOWN  195779     Assoc-voc             Widowed
# 5590    78           UNKNOWN  363134       HS-grad             Widowed
# 5632    45           UNKNOWN  189564       Masters  Married-civ-spouse
# 5766    62           UNKNOWN   97231  Some-college  Married-civ-spouse
# 5808    76           UNKNOWN  211574          10th  Married-civ-spouse
# 8447    67           UNKNOWN  244122     Assoc-voc             Widowed
# 9147    75           UNKNOWN  260543          10th             Widowed
# 11451   27           Private  147951       HS-grad       Never-married
# 19337   72           UNKNOWN   76860       HS-grad  Married-civ-spouse
# 19750   23           Private   72887       HS-grad       Never-married
# ...

# %%
df[df.salary == '>50K']
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 8       31           Private   45781       Masters       Never-married
# 9       42           Private  159449     Bachelors  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 11      30         State-gov  141297     Bachelors  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32539   71           UNKNOWN  287372     Doctorate  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32554   53           Private  321865       Masters  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# ...

# %%
lazy_riches = (df['hours-per-week'] == df['hours-per-week'].min()) & (df.salary == '>50K')
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
df[lazy_riches]
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    UNKNOWN   76043    HS-grad  Married-civ-spouse         UNKNOWN
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 20072  United-States   >50K

# %%
num_lazy_riches = df[lazy_riches].shape[0]
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = len(df[df['hours-per-week'] == df['hours-per-week'].min()])
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work minimum hours a week and have a salary\
of >50K by the people who work minimum hours a week: % {round(num_lazy_riches / num_min_workers*100)}")
# Out:
# Percentage of the people who work minimum hours a week and have a salaryof >50K by the people who work minimum hours a week: % 10

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Which country has the highest percentage of people who earn >50K?</p>

# %%
country_salary_df = df.groupby('native-country')[['salary']].count()
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# ...

# %%
# country_salary_df.loc['Iran'][0]
# Out:
# 43

# %%
country_salary_df_riches = df[df.salary == '>50K'].groupby('native-country')[['salary']].count()
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# ...

# %%
# country_salary_df_riches.loc['Iran'][0]
# Out:
# 18

# %%
# 18 / 43
# Out:
# 0.4186046511627907

# %%
(country_salary_df_riches / country_salary_df).sort_values(by="salary", ascending=False)
# Out:
#                               salary
# native-country
# Iran                        0.418605
# France                      0.413793
# India                       0.400000
# Taiwan                      0.392157
# Japan                       0.387097
# Yugoslavia                  0.375000
# Cambodia                    0.368421
# Italy                       0.342466
# England                     0.333333
# Canada                      0.322314
# Germany                     0.321168
# Philippines                 0.308081
# Hong                        0.300000
# Greece                      0.275862
# China                       0.266667
# Cuba                        0.263158
# UNKNOWN                     0.250859
# Scotland                    0.250000
# United-States               0.245808
# Hungary                     0.230769
# Ireland                     0.208333
# South                       0.200000
# Poland                      0.200000
# Thailand                    0.166667
# ...

# %%
rich_per_country = (country_salary_df_riches / country_salary_df).sort_values('salary', ascending=False)
rich_per_country
# Out:
#                               salary
# native-country
# Iran                        0.418605
# France                      0.413793
# India                       0.400000
# Taiwan                      0.392157
# Japan                       0.387097
# Yugoslavia                  0.375000
# Cambodia                    0.368421
# Italy                       0.342466
# England                     0.333333
# Canada                      0.322314
# Germany                     0.321168
# Philippines                 0.308081
# Hong                        0.300000
# Greece                      0.275862
# China                       0.266667
# Cuba                        0.263158
# UNKNOWN                     0.250859
# Scotland                    0.250000
# United-States               0.245808
# Hungary                     0.230769
# Ireland                     0.208333
# South                       0.200000
# Poland                      0.200000
# Thailand                    0.166667
# ...

# %%
rich_per_country[rich_per_country.salary == rich_per_country.salary.max()]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
#use iloc here

rich_per_country.sort_values('salary', ascending=False).iloc[[0]]
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14, 7))

df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12, 6))

df.loc[((df["native-country"] == "United-States")), "salary"].value_counts().plot.bar();

# %%
plt.figure(figsize=(12, 6))

df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %%
df["native-country"].value_counts()

# %% [markdown]
# ### <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:150%; text-align:center; border-radius:10px 10px;">Identify the most popular occupation for those who earn >50K in India.</p>

# %%
top_IN_occupation = (df['native-country'] == 'India') & (df.salary == '>50K')

top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt    education         marital-status  \
# 11      30         State-gov  141297    Bachelors     Married-civ-spouse
# 968     48           Private  164966    Bachelors     Married-civ-spouse
# 1327    52           Private  168381      HS-grad                Widowed
# 7258    42         State-gov  102343  Prof-school     Married-civ-spouse
# 7285    54         State-gov   93449      Masters     Married-civ-spouse
# 8124    36           Private  172104  Prof-school          Never-married
# 9939    43       Federal-gov  325706  Prof-school     Married-civ-spouse
# 10590   35           Private   98283  Prof-school          Never-married
# 10661   59           Private  122283  Prof-school     Married-civ-spouse
# 10736   30           Private  243190  Prof-school     Married-civ-spouse
# 11260   54           Private  225599      Masters     Married-civ-spouse
# 11384   34           Private   98283  Prof-school          Never-married
# ...

# %%
df[top_IN_occupation]['occupation'].value_counts()
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Sales                1
# Transport-moving     1
# Name: occupation, dtype: int64

# %%
df[top_IN_occupation]['occupation'].value_counts().index[0]
# Out:
# 'Prof-specialty'

# %%
 #use mode here
    
a =  df[top_IN_occupation]["occupation"].mode()[0]
a
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>
