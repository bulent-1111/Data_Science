# %% [markdown]
# <p style="text-align: center"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data from file

# %%
df = pd.read_csv("adult_eda.csv")

# %% [markdown]
# # Try to undersstand what the data looks like? What are types of the features? Are there any missing values? Do I need to eliminate some features?

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K
# 3             0             0              40  United-States  <=50K
# 4             0             0              40           Cuba  <=50K

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   31759.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.082843   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.576172   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Look at the value counts of columns that have object datatype and replace '?' like values with 'Unknown' word.

# %%
df.value_counts()[1:2]
# Out:
# age  workclass  fnlwgt  education  education-num  marital-status  occupation     relationship   race   sex   capital-gain  capital-loss  hours-per-week  native-country  salary
# 30   Private    144593  HS-grad    9.0            Never-married   Other-service  Not-in-family  Black  Male  0             0             40              ?               <=50K     2
# dtype: int64

# %%
df.groupby(['age','workclass']).mean()
# Out:
#                              fnlwgt  education-num  capital-gain  \
# age workclass
# 17  ?                 208757.968750       6.593750    549.218750
#     Federal-gov        99893.000000       7.000000      0.000000
#     Local-gov         188705.000000       6.642857      0.000000
#     Never-worked      237272.000000       6.000000      0.000000
#     Private           180368.013333       6.678082     27.260000
# ...                             ...            ...           ...
# 90  ?                 179175.285714       8.000000    198.857143
#     Federal-gov       195433.000000       9.000000      0.000000
#     Local-gov         195935.250000       9.750000   7367.750000
#     Private           149593.392857      10.321429   1386.535714
#     Self-emp-not-inc  173568.000000      10.666667   4510.000000
#
#                       capital-loss  hours-per-week
# age workclass
# 17  ?                     0.000000       26.625000
#     Federal-gov        1602.000000       40.000000
#     Local-gov           114.428571       23.857143
#     Never-worked          0.000000       30.000000
#     Private              44.293333       19.940000
# ...                            ...             ...
# 90  ?                   622.285714       22.714286
#     Federal-gov           0.000000       30.000000
#     Local-gov             0.000000       40.000000
#     Private              78.785714       40.428571
#     Self-emp-not-inc      0.000000       34.000000
#
# [481 rows x 5 columns]

# %%
df.select_dtypes(exclude=['int64','float64']).replace('?','Unknown')
# Out:
#               workclass   education      marital-status         occupation  \
# 0             State-gov   Bachelors       Never-married       Adm-clerical
# 1      Self-emp-not-inc   Bachelors  Married-civ-spouse    Exec-managerial
# 2               Private     HS-grad            Divorced  Handlers-cleaners
# 3               Private        11th  Married-civ-spouse  Handlers-cleaners
# 4               Private   Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...         ...                 ...                ...
# 32556           Private  Assoc-acdm  Married-civ-spouse       Tech-support
# 32557           Private     HS-grad  Married-civ-spouse  Machine-op-inspct
# 32558           Private     HS-grad             Widowed       Adm-clerical
# 32559           Private     HS-grad       Never-married       Adm-clerical
# 32560      Self-emp-inc     HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race     sex native-country salary
# 0      Not-in-family  White    Male  United-States  <=50K
# 1            Husband  White    Male  United-States  <=50K
# 2      Not-in-family  White    Male  United-States  <=50K
# 3            Husband  Black    Male  United-States  <=50K
# 4               Wife  Black  Female           Cuba  <=50K
# ...              ...    ...     ...            ...    ...
# 32556           Wife  White  Female  United-States  <=50K
# 32557        Husband  White    Male  United-States   >50K
# 32558      Unmarried  White  Female  United-States  <=50K
# 32559            NaN  White    Male  United-States  <=50K
# 32560           Wife  White  Female  United-States   >50K
#
# [32561 rows x 9 columns]

# %%
list = df.select_dtypes(exclude=['int64','float64']).columns # include number
list
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'salary'],
#       dtype='object')

# %%
for i in list:
    df[i].replace('?','Unknown',inplace=True)
    # print(i)

# %%
df['workclass']
# Out:
# 0               State-gov
# 1        Self-emp-not-inc
# 2                 Private
# 3                 Private
# 4                 Private
#                ...
# 32556             Private
# 32557             Private
# 32558             Private
# 32559             Private
# 32560        Self-emp-inc
# Name: workclass, Length: 32561, dtype: object

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'salary'],
#       dtype='object')

# %%
# df.select_dtypes(exclude=['int64','float64']).describe()
df.select_dtypes(include='object').describe()
# Out:
#        workclass education      marital-status      occupation relationship  \
# count      32561     32561               32561           32561        27493
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22696     10501               14976            4140        13193
#
#          race    sex native-country salary
# count   32561  32561          32561  32561
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27816  21790          29170  24720

# %%
df['workclass'].value_counts()
# Out:
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# Unknown              1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64

# %%
#look at workclass column here

# %%
df.sample()
# Out:
#        age workclass  fnlwgt     education  education-num marital-status  \
# 11815   30   Private  197886  Some-college           10.0  Never-married
#
#       occupation   relationship   race   sex  capital-gain  capital-loss  \
# 11815      Sales  Not-in-family  White  Male             0             0
#
#        hours-per-week native-country salary
# 11815              45  United-States   >50K

# %%
df.sample(7)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 20519   28    Private  189241          11th            7.0
# 29211   53  Local-gov  164300     Bachelors           13.0
# 9768    36    Private  218542  Some-college           10.0
# 18190   52  State-gov  104280  Some-college           10.0
# 22815   33    Private  175412           9th            5.0
# 2876    25    Private  503012       5th-6th            3.0
# 30429   38    Private  333651     Bachelors           13.0
#
#            marital-status         occupation   relationship   race     sex  \
# 20519  Married-civ-spouse  Handlers-cleaners            NaN  White    Male
# 29211            Divorced       Adm-clerical      Unmarried  White  Female
# 9768             Divorced       Craft-repair      Unmarried  White  Female
# 18190  Married-civ-spouse       Tech-support        Husband  White    Male
# 22815            Divorced       Craft-repair      Unmarried  White    Male
# 2876        Never-married       Craft-repair  Not-in-family  White    Male
# 30429  Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#        capital-gain  capital-loss  hours-per-week      native-country salary
# 20519             0             0              40       United-States  <=50K
# 29211             0             0              38  Dominican-Republic  <=50K
# 9768              0             0              40       United-States  <=50K
# 18190             0             0              50       United-States  <=50K
# 22815           114             0              55       United-States  <=50K
# 2876              0             0              40              Mexico  <=50K
# 30429         15024             0              70       United-States   >50K

# %%
#replace all '?' in whole df with 'Unknown'

# %%
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical            NaN  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Do education and education_num columns hold similar information? If so drop the appropriate choice between them.

# %%
df.sample(3)
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 24125   50           Private  206862   Masters           14.0
# 1557    41  Self-emp-not-inc  195124   HS-grad            9.0
# 3636    45           Private  304570      12th            8.0
#
#            marital-status         occupation   relationship  \
# 24125  Married-civ-spouse    Exec-managerial        Husband
# 1557        Never-married              Sales  Not-in-family
# 3636   Married-civ-spouse  Machine-op-inspct        Husband
#
#                      race   sex  capital-gain  capital-loss  hours-per-week  \
# 24125               White  Male             0             0              65
# 1557                White  Male             0             0              50
# 3636   Asian-Pac-Islander  Male             0             0              40
#
#       native-country salary
# 24125  United-States   >50K
# 1557         Unknown  <=50K
# 3636         Unknown  <=50K

# %%
df['education']
# Out:
# 0         Bachelors
# 1         Bachelors
# 2           HS-grad
# 3              11th
# 4         Bachelors
#             ...
# 32556    Assoc-acdm
# 32557       HS-grad
# 32558       HS-grad
# 32559       HS-grad
# 32560       HS-grad
# Name: education, Length: 32561, dtype: object

# %%
df[19851:19852]
# Out:
#        age workclass  fnlwgt education  education-num marital-status  \
# 19851   21   Private  136975   HS-grad            NaN  Never-married
#
#           occupation relationship   race   sex  capital-gain  capital-loss  \
# 19851  Other-service          NaN  White  Male             0             0
#
#        hours-per-week native-country salary
# 19851              40  United-States  <=50K

# %%
df['education-num'].sample(10)
# Out:
# 12918    12.0
# 21823    10.0
# 31975    10.0
# 2999      9.0
# 26675     9.0
# 299       9.0
# 17600     9.0
# 2313     12.0
# 5729     11.0
# 4761     13.0
# Name: education-num, dtype: float64

# %%
df['education-num'].head()
# Out:
# 0    13.0
# 1    13.0
# 2     9.0
# 3     7.0
# 4    13.0
# Name: education-num, dtype: float64

# %%
df.groupby('education')['education-num'].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
df.groupby('education')['education-num'].value_counts()
# Out:
# education     education-num
# 10th          6.0                916
# 11th          7.0               1146
# 12th          8.0                424
# 1st-4th       2.0                161
# 5th-6th       3.0                330
# 7th-8th       4.0                631
# 9th           5.0                503
# Assoc-acdm    12.0              1044
# Assoc-voc     11.0              1343
# Bachelors     13.0              5247
# Doctorate     16.0               405
# HS-grad       9.0              10215
# Masters       14.0              1687
# Preschool     1.0                 50
# Prof-school   15.0               559
# Some-college  10.0              7098
# Name: education-num, dtype: int64

# %%
ed = df['education'].unique()
ed
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
# ed_num = df['education-num'].dropna().unique()
ed_num  = np.array([13.,  9.,  7., 14.,  5., 10., 12.,   11., 4., 16., 15.,  3.,  6., 2.,  1.,  8.])
ed_num
# Out:
# array([13.,  9.,  7., 14.,  5., 10., 12., 11.,  4., 16., 15.,  3.,  6.,
#         2.,  1.,  8.])

# %%
ed_zip= dict(zip(ed,ed_num))
ed_zip
# Out:
# {'Bachelors': 13.0,
#  'HS-grad': 9.0,
#  '11th': 7.0,
#  'Masters': 14.0,
#  '9th': 5.0,
#  'Some-college': 10.0,
#  'Assoc-acdm': 12.0,
#  'Assoc-voc': 11.0,
#  '7th-8th': 4.0,
#  'Doctorate': 16.0,
#  'Prof-school': 15.0,
#  '5th-6th': 3.0,
#  '10th': 6.0,
#  '1st-4th': 2.0,
#  'Preschool': 1.0,
#  '12th': 8.0}

# %%
df['education'].replace(ed_zip, inplace=True)

# %%
df['education'].value_counts()
# Out:
# 9.0     10501
# 10.0     7291
# 13.0     5355
# 14.0     1723
# 11.0     1382
# 7.0      1175
# 12.0     1067
# 6.0       933
# 4.0       646
# 15.0      576
# 5.0       514
# 8.0       433
# 16.0      413
# 3.0       333
# 2.0       168
# 1.0        51
# Name: education, dtype: int64

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education-num      802
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
df.drop('education-num', axis=1, inplace=True)

df['education'].value_counts()
# Out:
# 9.0     10501
# 10.0     7291
# 13.0     5355
# 14.0     1723
# 11.0     1382
# 7.0      1175
# 12.0     1067
# 6.0       933
# 4.0       646
# 15.0      576
# 5.0       514
# 8.0       433
# 16.0      413
# 3.0       333
# 2.0       168
# 1.0        51
# Name: education, dtype: int64

# %%
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education, dtype: int64

# %%
# Out:
# 9.0     10215
# 10.0     7098
# 13.0     5247
# 14.0     1687
# 11.0     1343
# 7.0      1146
# 12.0     1044
# 6.0       916
# 4.0       631
# 15.0      559
# 5.0       503
# 8.0       424
# 16.0      405
# 3.0       330
# 2.0       161
# 1.0        50
# Name: education-num, dtype: int64

# %%
#drop one of them here

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %%
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# marital-status       0
# occupation           0
# relationship      5068
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country       0
# salary               0
# dtype: int64

# %% [markdown]
# ---
# ---

# %% [markdown]
# # Take a look at correlation between variables and also see if there are some outliers in any of the columns.

# %%
df.corr()
# Out:
#                      age    fnlwgt  education  capital-gain  capital-loss  \
# age             1.000000 -0.076646   0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000  -0.043195      0.000432     -0.010252
# education       0.036527 -0.043195   1.000000      0.122630      0.079923
# capital-gain    0.077674  0.000432   0.122630      1.000000     -0.031615
# capital-loss    0.057775 -0.010252   0.079923     -0.031615      1.000000
# hours-per-week  0.068756 -0.018768   0.148123      0.078409      0.054256
#
#                 hours-per-week
# age                   0.068756
# fnlwgt               -0.018768
# education             0.148123
# capital-gain          0.078409
# capital-loss          0.054256
# hours-per-week        1.000000

# %%
# Out:
#                      age    fnlwgt  capital-gain  capital-loss  hours-per-week
# age             1.000000 -0.076646      0.077674      0.057775        0.068756
# fnlwgt         -0.076646  1.000000      0.000432     -0.010252       -0.018768
# capital-gain    0.077674  0.000432      1.000000     -0.031615        0.078409
# capital-loss    0.057775 -0.010252     -0.031615      1.000000        0.054256
# hours-per-week  0.068756 -0.018768      0.078409      0.054256        1.000000

# %%
df.describe()
# Out:
#                 age        fnlwgt     education  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04  32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05     10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05      2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04      1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05      9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05     10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05     12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06     16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# Out:
#                 age        fnlwgt  capital-gain  capital-loss  hours-per-week
# count  32561.000000  3.256100e+04  32561.000000  32561.000000    32561.000000
# mean      38.581647  1.897784e+05   1077.648844     87.303830       40.437456
# std       13.640433  1.055500e+05   7385.292085    402.960219       12.347429
# min       17.000000  1.228500e+04      0.000000      0.000000        1.000000
# 25%       28.000000  1.178270e+05      0.000000      0.000000       40.000000
# 50%       37.000000  1.783560e+05      0.000000      0.000000       40.000000
# 75%       48.000000  2.370510e+05      0.000000      0.000000       45.000000
# max       90.000000  1.484705e+06  99999.000000   4356.000000       99.000000

# %%
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
IQR = q3 - q1
IQR
# Out:
# 20.0

# %%
#age column
IQR =

# %%
upper_lim = q3 + (1.5 * IQR)
upper_lim_age = upper_lim
upper_lim
# Out:
# 78.0

# %%
upper_lim=
# Out:
# 78.0

# %%
df[df["age"] >=   upper_lim  ]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 79    22
# 80    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 86     1
# 87     1
# Name: age, dtype: int64

# %%
df[df["age"] >=   **code here**  ]["age"].value_counts()
# Out:
# 90    43
# 78    23
# 80    22
# 79    22
# 81    20
# 82    12
# 84    10
# 83     6
# 88     3
# 85     3
# 87     1
# 86     1
# Name: age, dtype: int64

# %%
fig ,ax = plt.subplots(2,3,figsize=(20,7))
x = 0
y = 0
for column in df.select_dtypes('number').columns:
    
    df[column].plot(kind = "box", ax = ax[x,y])
    if y < 2:
        y += 1
    else:
        x += 1
        y = 0

# %%
df["hours-per-week"].sample(5)
# Out:
# 16174    40
# 16370    40
# 354      40
# 18138    40
# 9536     12
# Name: hours-per-week, dtype: int64

# %%
df[df["hours-per-week"] == 99].sample()
# Out:
#        age workclass  fnlwgt  education      marital-status occupation  \
# 10986   38   Private  111499        9.0  Married-civ-spouse      Sales
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 10986      Husband  White  Male             0          1977              99
#
#       native-country salary
# 10986  United-States   >50K

# %%
df[(df["hours-per-week"] == 99)].sample(10)
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 23179   31           Private  511289       HS-grad       Never-married
# 27809   30           Private   39386  Some-college  Married-civ-spouse
# 30766   42  Self-emp-not-inc   39539       HS-grad  Married-civ-spouse
# 10468   44  Self-emp-not-inc  277783       Masters       Never-married
# 26858   66           Private  262285     Bachelors  Married-civ-spouse
# 30992   40      Self-emp-inc  104235       Masters       Never-married
# 29751   51  Self-emp-not-inc   32372          12th  Married-civ-spouse
# 30036   40           Private   25005     Bachelors  Married-civ-spouse
# 17611   28  Self-emp-not-inc  104617       7th-8th       Never-married
# 10986   38           Private  111499       HS-grad  Married-civ-spouse
#
#             occupation    relationship   race     sex  capital-gain  \
# 23179  Farming-fishing   Not-in-family  White    Male          2907
# 27809  Exec-managerial         Husband  Black    Male             0
# 30766  Farming-fishing         Husband  White    Male             0
# 10468  Farming-fishing             NaN  White    Male             0
# 26858   Prof-specialty         Husband  White    Male             0
# 30992    Other-service             NaN  White    Male             0
# 29751    Other-service         Husband  White    Male             0
# 30036   Prof-specialty         Husband  White    Male         15024
# 17611    Other-service  Other-relative  White  Female             0
# 10986            Sales         Husband  White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 23179             0              99  United-States  <=50K
# 27809             0              99  United-States  <=50K
# 30766             0              99  United-States   >50K
# 10468             0              99  United-States  <=50K
# 26858             0              99  United-States  <=50K
# 30992             0              99  United-States  <=50K
# 29751             0              99  United-States  <=50K
# 30036             0              99  United-States   >50K
# 17611             0              99         Mexico  <=50K
# 10986          1977              99  United-States   >50K

# %%
Q1 = df['hours-per-week'].quantile(0.25)
Q3 = df['hours-per-week'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 5.0

# %%
#hours per week column
IQR =

# %%
upper_lim = Q3 + (1.5 * IQR)
upper_lim_hour =  upper_lim 
upper_lim
# Out:
# 52.5

# %%
upper_lim=
upper_lim

# %%
# find outlier values which extends the upper limit in both age and hours-per-week columns

# %%
df[(df['age']> upper_lim_age )  & (df['hours-per-week']> upper_lim_hour)]
# Out:
#        age     workclass  fnlwgt  education      marital-status  \
# 3777    80       Private   87518       10.0       Never-married
# 5370    90     Local-gov  227796       14.0  Married-civ-spouse
# 7481    83       Private  195507        9.0             Widowed
# 7720    84       Private  241065       14.0       Never-married
# 8806    90       Private   87372       15.0  Married-civ-spouse
# 11996   90       Private   40388       13.0       Never-married
# 12830   81       Private  201398       14.0             Widowed
# 15356   90       Private   90523        9.0             Widowed
# 24395   83  Self-emp-inc  153183       13.0  Married-civ-spouse
#
#              occupation   relationship   race   sex  capital-gain  \
# 3777     Prof-specialty  Not-in-family  White  Male             0
# 5370    Exec-managerial        Husband  White  Male         20051
# 7481    Protective-serv  Not-in-family  White  Male             0
# 7720     Prof-specialty  Not-in-family  White  Male             0
# 8806     Prof-specialty        Husband  White  Male         20051
# 11996   Exec-managerial  Not-in-family  White  Male             0
# 12830    Prof-specialty      Unmarried  White  Male             0
# 15356  Transport-moving      Unmarried  White  Male             0
# 24395   Exec-managerial        Husband  White  Male             0
#
#        capital-loss  hours-per-week native-country salary
# 3777           1816              60  United-States  <=50K
# 5370              0              60  United-States   >50K
# 7481              0              55  United-States  <=50K
# 7720              0              66  United-States  <=50K
# 8806              0              72  United-States   >50K
# 11996             0              55  United-States  <=50K
# 12830             0              60        Unknown  <=50K
# 15356             0              99  United-States  <=50K
# 24395          2392              55  United-States   >50K

# %%
# Out:
#        age     workclass  fnlwgt     education      marital-status  \
# 3777    80       Private   87518  Some-college       Never-married
# 5370    90     Local-gov  227796       Masters  Married-civ-spouse
# 7481    83       Private  195507       HS-grad             Widowed
# 7720    84       Private  241065       Masters       Never-married
# 8806    90       Private   87372   Prof-school  Married-civ-spouse
# 10546   78       Unknown   33186       7th-8th  Married-civ-spouse
# 11996   90       Private   40388     Bachelors       Never-married
# 12830   81       Private  201398       Masters             Widowed
# 15356   90       Private   90523       HS-grad             Widowed
# 24395   83  Self-emp-inc  153183     Bachelors  Married-civ-spouse
#
#              occupation   relationship   race   sex  capital-gain  \
# 3777     Prof-specialty  Not-in-family  White  Male             0
# 5370    Exec-managerial        Husband  White  Male         20051
# 7481    Protective-serv  Not-in-family  White  Male             0
# 7720     Prof-specialty  Not-in-family  White  Male             0
# 8806     Prof-specialty        Husband  White  Male         20051
# 10546           Unknown        Husband  White  Male             0
# 11996   Exec-managerial  Not-in-family  White  Male             0
# 12830    Prof-specialty      Unmarried  White  Male             0
# 15356  Transport-moving      Unmarried  White  Male             0
# 24395   Exec-managerial        Husband  White  Male             0
#
#        capital-loss  hours-per-week native-country salary
# 3777           1816              60  United-States  <=50K
# 5370              0              60  United-States   >50K
# 7481              0              55  United-States  <=50K
# 7720              0              66  United-States  <=50K
# 8806              0              72  United-States   >50K
# 10546             0              60  United-States  <=50K
# 11996             0              55  United-States  <=50K
# 12830             0              60        Unknown  <=50K
# 15356             0              99  United-States  <=50K
# 24395          2392              55  United-States   >50K

# %% [markdown]
# # After looking at the outliers you can drop the rows which actually does not make any sense.
# ** Hint: You can check age and hours per week columns. **

# %%
df[(df['age']> upper_lim_age )  & (df['hours-per-week']> upper_lim_hour)].index
# Out:
# Int64Index([3777, 5370, 7481, 7720, 8806, 11996, 12830, 15356, 24395], dtype='int64')

# %%
df.drop(df[(df['age']> upper_lim_age )  & (df['hours-per-week']> upper_lim_hour)].index, axis=0, inplace=True)

# %%
drop_index=

# %%
df[(df['age']> upper_lim_age )  & (df['hours-per-week']> upper_lim_hour)]
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %%
# check outlier values which extends the upper limit in both age and hours-per-week columns
# Out:
# Empty DataFrame
# Columns: [age, workclass, fnlwgt, education, marital-status, occupation, relationship, race, sex, capital-gain, capital-loss, hours-per-week, native-country, salary]
# Index: []

# %% [markdown]
# # Impute missing values in relationship column with 'Unmarried'. Also replace 'Not-in-family','Other-relative' values in this column with 'Unmarried'?

# %%
df['relationship'].value_counts()
# Out:
# Husband           13190
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
# Out:
# Husband           13189
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df_1 = df['relationship'].replace({'Not-in-family':'Unmarried','Other-relative' :'Unmarried'})
df_1.value_counts()
# Out:
# Husband      13190
# Unmarried    12726
# Wife          1568
# Name: relationship, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# Husband           13190
# Not-in-family      8301
# Unmarried          3444
# Wife               1568
# Other-relative      981
# Name: relationship, dtype: int64

# %%
df.relationship.value_counts()
# Out:
# Unmarried    17794
# Husband      13189
# Wife          1568
# Name: relationship, dtype: int64

# %% [markdown]
# ---
# # How many of each race are represented in this dataset?
# ---

# %%
race_count = df.race.value_counts()
race_count
# Out:
# White                 27807
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count = 
race_count
# Out:
# White                 27806
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
race_count.sort_values().plot.barh();

# %% [markdown]
# ---
# # What is the average age of men/women?
# ---

# %%
df.sample()
# Out:
#        age workclass  fnlwgt  education      marital-status     occupation  \
# 14971   36   Private  108103        9.0  Married-civ-spouse  Other-service
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 14971      Husband  White  Male             0             0              50
#
#       native-country salary
# 14971  United-States  <=50K

# %%
average_age_men = df.groupby('sex')['age'].mean()[1]
average_age_men
# Out:
# 39.41444378127726

# %%
average_age_men =
average_age_men
# Out:
# 39.41267217630854

# %%
round(average_age_men,1)
# Out:
# 39.4

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Male", "age"].value_counts().plot.bar();

# %%
average_age_women =  df.groupby('sex')['age'].mean()[0]
average_age_women
# Out:
# 36.85823043357163

# %%
average_age_women = 
average_age_women
# Out:
# 36.85823043357163

# %%
plt.figure(figsize = (15,7))
df.loc[df["sex"] == "Female", "age"].value_counts().plot.bar();

# %% [markdown]
# ---
# # What is the percentage of people who have a Bachelor's degree?
# ---

# %%
df.sample(3)
# Out:
#        age workclass  fnlwgt  education      marital-status       occupation  \
# 16345   68   Private  186350        9.0             Widowed  Exec-managerial
# 2649    28   Private  185957        9.0  Married-civ-spouse     Adm-clerical
# 25295   61   Unknown  187636       13.0            Divorced          Unknown
#
#         relationship   race     sex  capital-gain  capital-loss  \
# 16345  Not-in-family  White  Female             0             0
# 2649            Wife  White  Female             0             0
# 25295      Unmarried  White  Female             0             0
#
#        hours-per-week native-country salary
# 16345              10  United-States   >50K
# 2649               40  United-States  <=50K
# 25295              40  United-States  <=50K

# %%
ed_zip
# Out:
# {'Bachelors': 13.0,
#  'HS-grad': 9.0,
#  '11th': 7.0,
#  'Masters': 14.0,
#  '9th': 5.0,
#  'Some-college': 10.0,
#  'Assoc-acdm': 12.0,
#  'Assoc-voc': 11.0,
#  '7th-8th': 4.0,
#  'Doctorate': 16.0,
#  'Prof-school': 15.0,
#  '5th-6th': 3.0,
#  '10th': 6.0,
#  '1st-4th': 2.0,
#  'Preschool': 1.0,
#  '12th': 8.0}

# %%
df['education'].value_counts().sum()
# Out:
# 32552

# %%
df['education'].value_counts()[13.0]
# Out:
# 5353

# %%
bc = (df['education'].value_counts()[13.0]) / (df['education'].value_counts().sum() )  *100
bc
# Out:
# 16.44445809781273

# %%
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           645
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5353
# Doctorate         413
# HS-grad         10499
# Masters          1720
# Preschool          51
# Prof-school       575
# Some-college     7290
# Name: education, dtype: int64

# %%
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
upper = df['education'].value_counts().sum()

lower = df['education'].value_counts()[13.0]

percentage_bachelors = lower / upper * 100

percentage_bachelors
# Out:
# 16.44445809781273

# %%
upper = df['education'].value_counts().sum()

lower = df['education'].value_counts()[13.0]

percentage_bachelors = lower / upper * 100

percentage_bachelors
# Out:
# 16.444963288378236

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc[13.0]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
df["education"].value_counts(normalize=True)
# Out:
# 9.0     0.322530
# 10.0    0.223949
# 13.0    0.164445
# 14.0    0.052839
# 11.0    0.042455
# 7.0     0.036096
# 12.0    0.032778
# 6.0     0.028662
# 4.0     0.019845
# 15.0    0.017664
# 5.0     0.015790
# 8.0     0.013302
# 16.0    0.012687
# 3.0     0.010230
# 2.0     0.005161
# 1.0     0.001567
# Name: education, dtype: float64

# %%
df["education"].value_counts(normalize=True)
# Out:
# HS-grad         0.322540
# Some-college    0.223956
# Bachelors       0.164450
# Masters         0.052840
# Assoc-voc       0.042456
# 11th            0.036097
# Assoc-acdm      0.032779
# 10th            0.028663
# 7th-8th         0.019815
# Prof-school     0.017665
# 9th             0.015791
# 12th            0.013302
# Doctorate       0.012688
# 5th-6th         0.010230
# 1st-4th         0.005161
# Preschool       0.001567
# Name: education, dtype: float64

# %%
percentage_bachelors = df["education"].value_counts(normalize=True).loc["Bachelors"]*100
round(percentage_bachelors,1)
# Out:
# 16.4

# %%
print(f"The percentage of people who have a Bachelor's degree : %{round(percentage_bachelors,1)}")
# Out:
# The percentage of people who have a Bachelor's degree : %16.4

# %% [markdown]
# ---
# # What percentage of people with advanced education (`Bachelors`, `Masters`, or `Doctorate`) make more than 50K?
# ---

# %%
ed_zip
# Out:
# {'Bachelors': 13.0,
#  'HS-grad': 9.0,
#  '11th': 7.0,
#  'Masters': 14.0,
#  '9th': 5.0,
#  'Some-college': 10.0,
#  'Assoc-acdm': 12.0,
#  'Assoc-voc': 11.0,
#  '7th-8th': 4.0,
#  'Doctorate': 16.0,
#  'Prof-school': 15.0,
#  '5th-6th': 3.0,
#  '10th': 6.0,
#  '1st-4th': 2.0,
#  'Preschool': 1.0,
#  '12th': 8.0}

# %%
# ed_zip = {y:x for x,y in ed_zip.iteritems()}
ed_zip= dict(zip(ed_num,ed))
df['education'].replace(ed_zip, inplace=True)

# %%
df.sample()
# Out:
#       age  workclass  fnlwgt   education      marital-status    occupation  \
# 1407   39  Local-gov  352628  Assoc-acdm  Married-civ-spouse  Craft-repair
#
#      relationship   race     sex  capital-gain  capital-loss  hours-per-week  \
# 1407         Wife  White  Female             0             0              50
#
#      native-country salary
# 1407  United-States   >50K

# %%
df[(df['education'] =='Bachelors') | (df['education'] =='Masters') | (df['education'] =='Prof-school')|(df['education'] =='Doctorate') ]['salary'].value_counts()
# Out:
# <=50K    4155
# >50K     3906
# Name: salary, dtype: int64

# %%
df['salary'].value_counts() ### !!! ??? ***
# Out:
# <=50K    24714
# >50K      7838
# Name: salary, dtype: int64

# %%
# Out:
# <=50K    24713
# >50K      7838
# Name: salary, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
# Out:
# HS-grad         10499
# Some-college     7290
# Bachelors        5353
# Masters          1720
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           645
# Prof-school       575
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
higher_education =(df['education'] =='Bachelors') | (df['education'] =='Masters') | (df['education'] =='Prof-school')|(df['education'] =='Doctorate') 
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32552, dtype: bool

# %%
higher_education = 
higher_education
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Name: education, Length: 32551, dtype: bool

# %%
df_high_edu = df[(df['education'] =='Bachelors') | (df['education'] =='Masters') | (df['education'] =='Prof-school')|(df['education'] =='Doctorate') ]
df_high_edu
# Out:
#        age         workclass  fnlwgt    education      marital-status  \
# 0       39         State-gov   77516    Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311    Bachelors  Married-civ-spouse
# 4       28           Private  338409    Bachelors  Married-civ-spouse
# 5       37           Private  284582      Masters  Married-civ-spouse
# 8       31           Private   45781      Masters       Never-married
# ...    ...               ...     ...          ...                 ...
# 32539   71           Unknown  287372    Doctorate  Married-civ-spouse
# 32544   31           Private  199655      Masters            Divorced
# 32548   65  Self-emp-not-inc   99359  Prof-school       Never-married
# 32553   32           Private  116138      Masters       Never-married
# 32554   53           Private  321865      Masters  Married-civ-spouse
#
#             occupation   relationship                race     sex  \
# 0         Adm-clerical  Not-in-family               White    Male
# 1      Exec-managerial        Husband               White    Male
# 4       Prof-specialty           Wife               Black  Female
# 5      Exec-managerial           Wife               White  Female
# 8       Prof-specialty  Not-in-family               White  Female
# ...                ...            ...                 ...     ...
# 32539          Unknown        Husband               White    Male
# 32544    Other-service  Not-in-family               Other  Female
# 32548   Prof-specialty  Not-in-family               White    Male
# 32553     Tech-support  Not-in-family  Asian-Pac-Islander    Male
# 32554  Exec-managerial        Husband               White    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# 5                 0             0              40  United-States  <=50K
# 8             14084             0              50  United-States   >50K
# ...             ...           ...             ...            ...    ...
# 32539             0             0              10  United-States   >50K
# 32544             0             0              30  United-States  <=50K
# 32548          1086             0              60  United-States  <=50K
# 32553             0             0              11         Taiwan  <=50K
# 32554             0             0              40  United-States   >50K
#
# [8061 rows x 14 columns]

# %%
### high educationa 'Prof-school' u katmamissiniz????? 
df_high_edu =
df_high_edu
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 0       39         State-gov   77516  Bachelors       Never-married
# 1       50  Self-emp-not-inc   83311  Bachelors  Married-civ-spouse
# 4       28           Private  338409  Bachelors  Married-civ-spouse
# 5       37           Private  284582    Masters  Married-civ-spouse
# 8       31           Private   45781    Masters       Never-married
# ...    ...               ...     ...        ...                 ...
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32544   31           Private  199655    Masters            Divorced
# 32553   32           Private  116138    Masters       Never-married
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 0         Adm-clerical    Unmarried               White    Male          2174
# 1      Exec-managerial      Husband               White    Male             0
# 4       Prof-specialty         Wife               Black  Female             0
# 5      Exec-managerial         Wife               White  Female             0
# 8       Prof-specialty    Unmarried               White  Female         14084
# ...                ...          ...                 ...     ...           ...
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539          Unknown      Husband               White    Male             0
# 32544    Other-service    Unmarried               Other  Female             0
# 32553     Tech-support    Unmarried  Asian-Pac-Islander    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 0                 0              40  United-States  <=50K
# 1                 0              13  United-States  <=50K
# 4                 0              40           Cuba  <=50K
# 5                 0              40  United-States  <=50K
# 8                 0              50  United-States   >50K
# ...             ...             ...            ...    ...
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32544             0              30  United-States  <=50K
# 32553             0              11         Taiwan  <=50K
# 32554             0              40  United-States   >50K
#
# [7486 rows x 14 columns]

# %%
# Out:
#        age         workclass  fnlwgt  education      marital-status  \
# 8       31           Private   45781    Masters       Never-married
# 9       42           Private  159449  Bachelors  Married-civ-spouse
# 11      30         State-gov  141297  Bachelors  Married-civ-spouse
# 19      43  Self-emp-not-inc  292175    Masters            Divorced
# 20      40           Private  193524  Doctorate  Married-civ-spouse
# ...    ...               ...     ...        ...                 ...
# 32533   54           Private  337992  Bachelors  Married-civ-spouse
# 32536   34           Private  160216  Bachelors       Never-married
# 32538   38           Private  139180  Bachelors            Divorced
# 32539   71           Unknown  287372  Doctorate  Married-civ-spouse
# 32554   53           Private  321865    Masters  Married-civ-spouse
#
#             occupation relationship                race     sex  capital-gain  \
# 8       Prof-specialty    Unmarried               White  Female         14084
# 9      Exec-managerial      Husband               White    Male          5178
# 11      Prof-specialty      Husband  Asian-Pac-Islander    Male             0
# 19     Exec-managerial    Unmarried               White  Female             0
# 20      Prof-specialty      Husband               White    Male             0
# ...                ...          ...                 ...     ...           ...
# 32533  Exec-managerial      Husband  Asian-Pac-Islander    Male             0
# 32536  Exec-managerial    Unmarried               White  Female             0
# 32538   Prof-specialty    Unmarried               Black  Female         15020
# 32539          Unknown      Husband               White    Male             0
# 32554  Exec-managerial      Husband               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 8                 0              50  United-States   >50K
# 9                 0              40  United-States   >50K
# 11                0              40          India   >50K
# 19                0              45  United-States   >50K
# 20                0              60  United-States   >50K
# ...             ...             ...            ...    ...
# 32533             0              50          Japan   >50K
# 32536             0              55  United-States   >50K
# 32538             0              45  United-States   >50K
# 32539             0              10  United-States   >50K
# 32554             0              40  United-States   >50K
#
# [3484 rows x 14 columns]

# %%
df_high_edu = df[(df['education'] =='Bachelors') | (df['education'] =='Masters') |(df['education'] =='Doctorate') ]

# %%
count = df_high_edu['education'].count()
count
# Out:
# 7486

# %%
df['education'].count()
# Out:
# 32552

# %%
count =

# %%
perc_high_edu =     df_high_edu['education'].count() / df['education'].count() 
perc_high_edu
# Out:
# 0.22997050872450234

# %%
perc_high_edu
# Out:
# 0.10703204202635863

# %%
print(f"Percentage of people with advanced education make more than 50K : {round(perc_high_edu * 100, 2)}")
# Out:
# Percentage of people with advanced education make more than 50K : 23.0

# %% [markdown]
# ---
# # What percentage of people without advanced education make more than 50K?
# ---

# %%
lower_education =

# %%
df_low_edu = 
df_low_edu
# Out:
#        age         workclass  fnlwgt     education         marital-status  \
# 2       38           Private  215646       HS-grad               Divorced
# 3       53           Private  234721          11th     Married-civ-spouse
# 6       49           Private  160187           9th  Married-spouse-absent
# 7       52  Self-emp-not-inc  209642       HS-grad     Married-civ-spouse
# 10      37           Private  280464  Some-college     Married-civ-spouse
# ...    ...               ...     ...           ...                    ...
# 32556   27           Private  257302    Assoc-acdm     Married-civ-spouse
# 32557   40           Private  154374       HS-grad     Married-civ-spouse
# 32558   58           Private  151910       HS-grad                Widowed
# 32559   22           Private  201490       HS-grad          Never-married
# 32560   52      Self-emp-inc  287927       HS-grad     Married-civ-spouse
#
#               occupation relationship   race     sex  capital-gain  \
# 2      Handlers-cleaners    Unmarried  White    Male             0
# 3      Handlers-cleaners      Husband  Black    Male             0
# 6          Other-service    Unmarried  Black  Female             0
# 7        Exec-managerial      Husband  White    Male             0
# 10       Exec-managerial      Husband  Black    Male             0
# ...                  ...          ...    ...     ...           ...
# 32556       Tech-support         Wife  White  Female             0
# 32557  Machine-op-inspct      Husband  White    Male             0
# 32558       Adm-clerical    Unmarried  White  Female             0
# 32559       Adm-clerical    Unmarried  White    Male             0
# 32560    Exec-managerial         Wife  White  Female         15024
#
#        capital-loss  hours-per-week native-country salary
# 2                 0              40  United-States  <=50K
# 3                 0              40  United-States  <=50K
# 6                 0              16        Jamaica  <=50K
# 7                 0              45  United-States   >50K
# 10                0              80  United-States   >50K
# ...             ...             ...            ...    ...
# 32556             0              38  United-States  <=50K
# 32557             0              40  United-States   >50K
# 32558             0              40  United-States  <=50K
# 32559             0              20  United-States  <=50K
# 32560             0              40  United-States   >50K
#
# [25065 rows x 14 columns]

# %%
# Out:
#        age         workclass  fnlwgt     education      marital-status  \
# 7       52  Self-emp-not-inc  209642       HS-grad  Married-civ-spouse
# 10      37           Private  280464  Some-college  Married-civ-spouse
# 14      40           Private  121772     Assoc-voc  Married-civ-spouse
# 27      54           Unknown  180211  Some-college  Married-civ-spouse
# 38      31           Private   84154  Some-college  Married-civ-spouse
# ...    ...               ...     ...           ...                 ...
# 32518   57         Local-gov  110417       HS-grad  Married-civ-spouse
# 32519   46           Private  364548  Some-college  Married-civ-spouse
# 32545   39         Local-gov  111499    Assoc-acdm  Married-civ-spouse
# 32557   40           Private  154374       HS-grad  Married-civ-spouse
# 32560   52      Self-emp-inc  287927       HS-grad  Married-civ-spouse
#
#               occupation relationship                race     sex  \
# 7        Exec-managerial      Husband               White    Male
# 10       Exec-managerial      Husband               Black    Male
# 14          Craft-repair      Husband  Asian-Pac-Islander    Male
# 27               Unknown      Husband  Asian-Pac-Islander    Male
# 38                 Sales      Husband               White    Male
# ...                  ...          ...                 ...     ...
# 32518       Craft-repair      Husband               White    Male
# 32519    Exec-managerial      Husband               White    Male
# 32545       Adm-clerical         Wife               White  Female
# 32557  Machine-op-inspct      Husband               White    Male
# 32560    Exec-managerial         Wife               White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 7                 0             0              45  United-States   >50K
# 10                0             0              80  United-States   >50K
# 14                0             0              40        Unknown   >50K
# 27                0             0              60          South   >50K
# 38                0             0              38        Unknown   >50K
# ...             ...           ...             ...            ...    ...
# 32518         99999             0              40  United-States   >50K
# 32519             0             0              48  United-States   >50K
# 32545             0             0              20  United-States   >50K
# 32557             0             0              40  United-States   >50K
# 32560         15024             0              40  United-States   >50K
#
# [4354 rows x 14 columns]

# %%
count =

# %%
count
# Out:
# 4354

# %%
perc_low_edu =

# %%
print(f"Percentage of people without advanced education make more than 50K : {round(perc_low_edu * 100 ,2)}")
# Out:
# Percentage of people without advanced education make more than 50K : 13.38

# %%
if perc_high_edu > perc_low_edu :
    print("More education more money!")
else:
    print("Education has no clear effet on salary. You should investigate some other features also.")
# Out:
# Education has no clear effet on salary. You should investigate some other features also.

# %% [markdown]
# ---
# # What percentage of the people who work the minimum number of hours per week have a salary of >50K?
# ---

# %%
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1471
# 35     1297
#       ...
# 92        1
# 94        1
# 87        1
# 74        1
# 82        1
# Name: hours-per-week, Length: 94, dtype: int64

# %%
lazy_riches = 
lazy_riches
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
# Out:
#        age  workclass  fnlwgt  education      marital-status      occupation  \
# 189     58  State-gov  109567  Doctorate  Married-civ-spouse  Prof-specialty
# 20072   65    Unknown   76043    HS-grad  Married-civ-spouse         Unknown
#
#       relationship   race   sex  capital-gain  capital-loss  hours-per-week  \
# 189        Husband  White  Male             0             0               1
# 20072      Husband  White  Male             0             0               1
#
#       native-country salary
# 189    United-States   >50K
# 20072  United-States   >50K

# %%
num_lazy_riches = 
num_lazy_riches
# Out:
# 2

# %%
num_min_workers = 
num_min_workers
# Out:
# 20

# %%
print (f"Percentage of the people who work the minimum number of hours per week have a salary of >50K : % {round(num_lazy_riches/num_min_workers*100)}")
# Out:
# Percentage of the people who work the minimum number of hours per week have a salary of >50K : % 10

# %% [markdown]
#  ---
#  # What country has the highest percentage of people that earn >50K?
#  ---

# %%
country_salary_df =
country_salary_df
# Out:
#                             salary
# native-country
# Cambodia                        19
# Canada                         121
# China                           75
# Columbia                        59
# Cuba                            95
# Dominican-Republic              70
# Ecuador                         28
# El-Salvador                    106
# England                         90
# France                          29
# Germany                        137
# Greece                          29
# Guatemala                       64
# Haiti                           44
# Holand-Netherlands               1
# Honduras                        13
# Hong                            20
# Hungary                         13
# India                          100
# Iran                            43
# Ireland                         24
# Italy                           73
# Jamaica                         81
# Japan                           62
# Laos                            18
# Mexico                         643
# Nicaragua                       34
# Outlying-US(Guam-USVI-etc)      14
# Peru                            31
# Philippines                    198
# Poland                          60
# Portugal                        37
# Puerto-Rico                    114
# Scotland                        12
# South                           80
# Taiwan                          51
# Thailand                        18
# Trinadad&Tobago                 19
# United-States                29161
# Unknown                        582
# Vietnam                         67
# Yugoslavia                      16

# %%
country_salary_df_riches = 
country_salary_df_riches
# Out:
#                     salary
# native-country
# Cambodia                 7
# Canada                  39
# China                   20
# Columbia                 2
# Cuba                    25
# Dominican-Republic       2
# Ecuador                  4
# El-Salvador              9
# England                 30
# France                  12
# Germany                 44
# Greece                   8
# Guatemala                3
# Haiti                    4
# Honduras                 1
# Hong                     6
# Hungary                  3
# India                   40
# Iran                    18
# Ireland                  5
# Italy                   25
# Jamaica                 10
# Japan                   24
# Laos                     2
# Mexico                  33
# Nicaragua                2
# Peru                     2
# Philippines             61
# Poland                  12
# Portugal                 4
# Puerto-Rico             12
# Scotland                 3
# South                   16
# Taiwan                  20
# Thailand                 3
# Trinadad&Tobago          2
# United-States         7168
# Unknown                146
# Vietnam                  5
# Yugoslavia               6

# %%
rich_per_country =
rich_per_country
# Out:
#                               salary
# native-country
# Dominican-Republic          0.028571
# Columbia                    0.033898
# Guatemala                   0.046875
# Mexico                      0.051322
# Nicaragua                   0.058824
# Peru                        0.064516
# Vietnam                     0.074627
# Honduras                    0.076923
# El-Salvador                 0.084906
# Haiti                       0.090909
# Trinadad&Tobago             0.105263
# Puerto-Rico                 0.105263
# Portugal                    0.108108
# Laos                        0.111111
# Jamaica                     0.123457
# Ecuador                     0.142857
# Thailand                    0.166667
# Poland                      0.200000
# South                       0.200000
# Ireland                     0.208333
# Hungary                     0.230769
# United-States               0.245808
# Scotland                    0.250000
# Unknown                     0.250859
# Cuba                        0.263158
# China                       0.266667
# Greece                      0.275862
# Hong                        0.300000
# Philippines                 0.308081
# Germany                     0.321168
# Canada                      0.322314
# England                     0.333333
# Italy                       0.342466
# Cambodia                    0.368421
# Yugoslavia                  0.375000
# Japan                       0.387097
# Taiwan                      0.392157
# India                       0.400000
# France                      0.413793
# Iran                        0.418605
# Holand-Netherlands               NaN
# Outlying-US(Guam-USVI-etc)       NaN

# %%
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
#use iloc here
# Out:
#                   salary
# native-country
# Iran            0.418605

# %%
plt.figure(figsize=(14,7))
df.loc[df["salary"] == ">50K", "native-country"].value_counts().plot(kind="bar");

# %%
plt.figure(figsize=(12,6))
df.loc[((df["native-country"] == "Iran")), "salary"].value_counts().plot.bar();

# %% [markdown]
# ---
# # Identify the most popular occupation for those who earn >50K in India.
# ---

# %%
top_IN_occupation =

top_IN_occupation
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32551, dtype: bool

# %%
df[top_IN_occupation]
# Out:
#        age         workclass  fnlwgt    education         marital-status  \
# 11      30         State-gov  141297    Bachelors     Married-civ-spouse
# 968     48           Private  164966    Bachelors     Married-civ-spouse
# 1327    52           Private  168381      HS-grad                Widowed
# 7258    42         State-gov  102343  Prof-school     Married-civ-spouse
# 7285    54         State-gov   93449      Masters     Married-civ-spouse
# 8124    36           Private  172104  Prof-school          Never-married
# 9939    43       Federal-gov  325706  Prof-school     Married-civ-spouse
# 10590   35           Private   98283  Prof-school          Never-married
# 10661   59           Private  122283  Prof-school     Married-civ-spouse
# 10736   30           Private  243190  Prof-school     Married-civ-spouse
# 11260   54           Private  225599      Masters     Married-civ-spouse
# 11384   34           Private   98283  Prof-school          Never-married
# 13422   53           Private  366957    Bachelors     Married-civ-spouse
# 13551   40           Private  220977    Doctorate     Married-civ-spouse
# 13862   45           Private  209912    Bachelors     Married-civ-spouse
# 16017   41           Private  207578   Assoc-acdm     Married-civ-spouse
# 16778   43           Private  242968      Masters     Married-civ-spouse
# 16923   41           Private  143003    Assoc-voc     Married-civ-spouse
# 17259   57      Self-emp-inc  123053  Prof-school     Married-civ-spouse
# 17834   29  Self-emp-not-inc  341672      HS-grad  Married-spouse-absent
# 20417   42      Self-emp-inc   23510      Masters               Divorced
# 20465   39           Private  198654  Prof-school     Married-civ-spouse
# 21128   30           Private  122889      Masters     Married-civ-spouse
# 23474   55         State-gov  120781    Doctorate     Married-civ-spouse
# 24154   46           Private  229737    Bachelors     Married-civ-spouse
# 25739   35      Self-emp-inc   79586      Masters     Married-civ-spouse
# 26305   27           Private  207352    Bachelors     Married-civ-spouse
# 26356   34           Private   99872      Masters     Married-civ-spouse
# 27670   61           Private   80896      Masters     Married-civ-spouse
# 28264   51  Self-emp-not-inc  120781  Prof-school     Married-civ-spouse
# 28433   42           Private  198341      Masters     Married-civ-spouse
# 28452   53           Private   70387      Masters     Married-civ-spouse
# 28557   34           Private  165737      Masters     Married-civ-spouse
# 28651   45  Self-emp-not-inc  216402  Prof-school     Married-civ-spouse
# 28798   30  Self-emp-not-inc  116666      Masters               Divorced
# 30111   41       Federal-gov  219155  Prof-school     Married-civ-spouse
# 30152   48           Private  119471    Doctorate     Married-civ-spouse
# 30833   25           Private  110978   Assoc-acdm     Married-civ-spouse
# 31327   38         State-gov  125499    Bachelors     Married-civ-spouse
# 31357   23           Private  143003      Masters     Married-civ-spouse
#
#              occupation relationship                race     sex  \
# 11       Prof-specialty      Husband  Asian-Pac-Islander    Male
# 968     Exec-managerial      Husband  Asian-Pac-Islander    Male
# 1327      Other-service    Unmarried  Asian-Pac-Islander  Female
# 7258     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 7285     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 8124     Prof-specialty    Unmarried               Other    Male
# 9939     Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10590    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 10661    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 10736    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11260    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 11384      Tech-support    Unmarried  Asian-Pac-Islander    Male
# 13422   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13551   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 13862   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16017   Exec-managerial      Husband               Black    Male
# 16778   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 16923     Other-service      Husband  Asian-Pac-Islander    Male
# 17259    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 17834  Transport-moving    Unmarried  Asian-Pac-Islander    Male
# 20417   Exec-managerial    Unmarried  Asian-Pac-Islander    Male
# 20465    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 21128    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 23474    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 24154             Sales      Husband               White    Male
# 25739    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 26305      Tech-support      Husband  Asian-Pac-Islander    Male
# 26356   Exec-managerial      Husband  Asian-Pac-Islander    Male
# 27670    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28264    Prof-specialty      Husband               Other    Male
# 28433    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28452    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28557    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28651    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 28798    Prof-specialty    Unmarried  Asian-Pac-Islander    Male
# 30111    Prof-specialty      Husband               White    Male
# 30152    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 30833      Adm-clerical         Wife  Asian-Pac-Islander  Female
# 31327    Prof-specialty      Husband  Asian-Pac-Islander    Male
# 31357    Prof-specialty      Husband  Asian-Pac-Islander    Male
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 11                0             0              40          India   >50K
# 968               0             0              40          India   >50K
# 1327              0             0              40          India   >50K
# 7258              0             0              72          India   >50K
# 7285              0             0              40          India   >50K
# 8124              0             0              40          India   >50K
# 9939              0             0              50          India   >50K
# 10590             0             0              40          India   >50K
# 10661         99999             0              40          India   >50K
# 10736             0             0              20          India   >50K
# 11260          7298             0              40          India   >50K
# 11384             0          1564              40          India   >50K
# 13422         99999             0              50          India   >50K
# 13551          3103             0              40          India   >50K
# 13862             0             0              40          India   >50K
# 16017             0             0              50          India   >50K
# 16778             0             0              40          India   >50K
# 16923          7298             0              60          India   >50K
# 17259         15024             0              50          India   >50K
# 17834             0          1564              50          India   >50K
# 20417             0          2201              60          India   >50K
# 20465             0          2415              67          India   >50K
# 21128             0             0              50          India   >50K
# 23474             0             0              40          India   >50K
# 24154             0             0              50          India   >50K
# 25739             0             0              40          India   >50K
# 26305             0             0              40          India   >50K
# 26356          3103             0              40          India   >50K
# 27670             0             0              45          India   >50K
# 28264         99999             0              70          India   >50K
# 28433             0          1902              55          India   >50K
# 28452          4386             0              40          India   >50K
# 28557             0             0              43          India   >50K
# 28651             0             0              50          India   >50K
# 28798             0             0              50          India   >50K
# 30111             0             0              50          India   >50K
# 30152             0             0              40          India   >50K
# 30833             0             0              37          India   >50K
# 31327          7688             0              60          India   >50K
# 31357             0          1887              50          India   >50K

# %%
# Out:
# Prof-specialty      25
# Exec-managerial      8
# Other-service        2
# Tech-support         2
# Adm-clerical         1
# Sales                1
# Transport-moving     1
# Name: occupation, dtype: int64

# %%
# Out:
# 'Prof-specialty'

# %%
a =  #use mode here
a
# Out:
# 'Prof-specialty'

# %%
print(f"{a} the most popular occupation for those who earn >50K in India.")
# Out:
# Prof-specialty the most popular occupation for those who earn >50K in India.

# %% [markdown]
# ----
# ---
