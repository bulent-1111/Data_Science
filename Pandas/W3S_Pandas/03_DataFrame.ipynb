# %%
import pandas as pd

data = {
  "calories": [420, 380, 390, 120, 880, 560, 320, 188, 216],
  "duration": [50, 40, 45, 20, 15, 25, 30, 40, 60]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       120        20
# 4       880        15
# 5       560        25
# 6       320        30
# 7       188        40
# 8       216        60

# %%
#  1. satirdaki veriyi Series olarak döndürür
#  1 index numarasi degil 1 numarali etikete sahip olan satir
df.loc[1]
# Out:
# calories    380
# duration     40
# Name: 1, dtype: int64

# %%
df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
# 3       120        20
# 4       880        15
# 5       560        25
# 6       320        30
# 7       188        40
# 8       216        60

# %%
# index listesi kullanarak yapmak 
# liste oldugu icin sadece liste indeylerindeki verileri yazar
df.loc[[3,7,1]]
# Out:
#    calories  duration
# 3       120        20
# 7       188        40
# 1       380        40

# %%
# DataFrame indexlerini kendimiz adlandiralim

data = {
  "calories": [420, 380, 390, 120, 880, 560, 320, 188, 216],
  "duration": [50, 40, 45, 20, 15, 25, 30, 40, 60]
}

#load data into a DataFrame object:
df = pd.DataFrame(data, index = ['day1','day2','day3','day4','day5','day6','day7','day8','day9'] )
df
# Out:
#       calories  duration
# day1       420        50
# day2       380        40
# day3       390        45
# day4       120        20
# day5       880        15
# day6       560        25
# day7       320        30
# day8       188        40
# day9       216        60

# %%
print(df.loc["day8"])
# Out:
# calories    188
# duration     40
# Name: day8, dtype: int64

# %%
#  dosyadan data frame e csv dosyasi yüklemek
df = pd.read_csv("data.csv", encoding ='unicode_escape')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...
