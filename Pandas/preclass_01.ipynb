# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Noah"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "noahseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2     Noah   Seaborn     noahseaborn@email.com

# %%
df.iloc[1,2]
# Out:
# 'robertdeepdive@email.com'

# %%
import numpy as np
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside, inside))
print(hier_index)
hier_index = pd.MultiIndex.from_tuples(hier_index)
print(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
# [('A1', 1), ('A1', 2), ('A1', 3), ('A2', 1), ('A2', 2), ('A2', 3)]
# MultiIndex([('A1', 1),
#             ('A1', 2),
#             ('A1', 3),
#             ('A2', 1),
#             ('A2', 2),
#             ('A2', 3)],
#            )
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data.loc['A1']
# Out:
#           X         Y
# 1  2.706850  0.628133
# 2  0.907969  0.503826
# 3  0.651118 -0.319318

# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Noah"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "noahseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2     Noah   Seaborn     noahseaborn@email.com

# %%
df['last']
# Out:
# 0       Stone
# 1    Deepdive
# 2     Seaborn
# Name: last, dtype: object

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
data[['city','age']]
# Out:
#       city  age
# 0  Gurgaon   10
# 1    Delhi   22
# 2   Mumbai   13
# 3    Delhi   21
# 4   Mumbai   12
# 5    Delhi   11
# 6   Mumbai   17

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'B', 'B', 'A', 'A'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       B    Delhi      M            pink
# 4   12       B   Mumbai      M           black
# 5   11       A    Delhi      M           green
# 6   17       A   Mumbai      F             red

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       D    Delhi      M            pink
# 4   12       E   Mumbai      M           black
# 5   11       F    Delhi      M           green
# 6   17       G   Mumbai      F             red

# %%
data.reset_index(inplace=True)
data
# Out:
#    index  age section     city gender favourite_color
# 0      0   10       A  Gurgaon      M             red
# 1      1   22       B    Delhi      F            blue
# 2      2   13       C   Mumbai      F          yellow
# 3      3   21       D    Delhi      M            pink
# 4      4   12       E   Mumbai      M           black
# 5      5   11       F    Delhi      M           green
# 6      6   17       G   Mumbai      F             red

# %%
data.set_index(keys='section', inplace=True)
data
# Out:
#          index  age     city gender favourite_color
# section
# A            0   10  Gurgaon      M             red
# B            1   22    Delhi      F            blue
# C            2   13   Mumbai      F          yellow
# D            3   21    Delhi      M            pink
# E            4   12   Mumbai      M           black
# F            5   11    Delhi      M           green
# G            6   17   Mumbai      F             red

# %%
# data.loc[1]

# data.loc[2]

data.loc['B']
# Out:
# index                  1
# age                   22
# city               Delhi
# gender                 F
# favourite_color     blue
# Name: B, dtype: object

# %%
df = pd.DataFrame(np.arange(12).reshape(3, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis=1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
df.drop([0, 1], axis=0)
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %%
df.drop([0,1])
# Out:
#    A  B   C   D
# 2  8  9  10  11

# %%
import pandas as pd
people_dict={"first":["Richard", "Robert", "Noah"],
             "last" :["Stone", "Deepdive", "Seaborn"],
             "email": ["richardstone@email.com", "robertdeepdive@email.com", 
                        "noahseaborn@email.com"]}
df=pd.DataFrame(people_dict)
df
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
# 2     Noah   Seaborn     noahseaborn@email.com

# %%
df[(df['first']=="Richard") | (df['last'] == 'Deepdive')]
# Out:
#      first      last                     email
# 0  Richard     Stone    richardstone@email.com
# 1   Robert  Deepdive  robertdeepdive@email.com
